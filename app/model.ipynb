# %%
print("testing kernal")
# Out:
# testing kernal

# %%
cources =  ["Course A", "Course B", "Course C"]
t1 = ", ".join(cources)
print(t1)
print(cources)
# Out:
# Course A, Course B, Course C
# ['Course A', 'Course B', 'Course C']
